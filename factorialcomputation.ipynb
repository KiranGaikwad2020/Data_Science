# %% [markdown]
# <a href="https://colab.research.google.com/github/KiranGaikwad2020/Data_Science/blob/Dev/factorialcomputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    """Calculates the factorial of a non-negative integer n."""
    if n == 0:
        return 1
    else:
        res = 1
        for i in range(1, n + 1):
            res *= i
        return res

# Example usage with user input:
try:
    number_str = input("Enter a non-negative integer: ")
    number = int(number_str)
    if number < 0:
        print("Factorial is not defined for negative numbers.")
    else:
        result = factorial(number)
        print(f"The factorial of {number} is {result}")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a non-negative integer: 7
# The factorial of 7 is 5040
